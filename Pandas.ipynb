# %%
import pandas as pd
df = pd.read_csv('QueryResults.csv', names=['DATE', 'TAGS', 'POST'])
df.head()
# Out:
#                   DATE        TAGS   POST
# 0                    m     TagName    NaN
# 1  2008-07-01 00:00:00          c#    3.0
# 2  2008-08-01 00:00:00    assembly    8.0
# 3  2008-08-01 00:00:00  javascript  162.0
# 4  2008-08-01 00:00:00           c   85.0

# %%
df.tail()
# Out:
#                      DATE   TAGS    POST
# 1987  2020-07-01 00:00:00      r  5694.0
# 1988  2020-07-01 00:00:00     go   743.0
# 1989  2020-07-01 00:00:00   ruby   775.0
# 1990  2020-07-01 00:00:00   perl   182.0
# 1991  2020-07-01 00:00:00  swift  3607.0

# %%
df.DATE = pd.to_datetime(df.DATE,  errors='coerce')
df.head()
# Out:
#         DATE        TAGS   POST
# 0        NaT     TagName    NaN
# 1 2008-07-01          c#    3.0
# 2 2008-08-01    assembly    8.0
# 3 2008-08-01  javascript  162.0
# 4 2008-08-01           c   85.0

# %%
df.groupby('DATE').count()
# Out:
#             TAGS  POST
# DATE
# 2008-07-01     1     1
# 2008-08-01    11    11
# 2008-09-01    12    12
# 2008-10-01    11    11
# 2008-11-01    12    12
# ...          ...   ...
# 2020-03-01    14    14
# 2020-04-01    14    14
# 2020-05-01    14    14
# 2020-06-01    14    14
# 2020-07-01    14    14
#
# [145 rows x 2 columns]

# %%
df.groupby('TAGS').count()
# Out:
#             DATE  POST
# TAGS
# TagName        1     0
# assembly     144   144
# c            144   144
# c#           145   145
# c++          144   144
# delphi       144   144
# go           129   129
# java         144   144
# javascript   144   144
# perl         144   144
# php          144   144
# python       144   144
# r            142   142
# ruby         144   144
# swift        135   135

# %%
df.count()
# Out:
# DATE    1991
# TAGS    1992
# POST    1991
# dtype: int64

# %%
df.groupby('TAGS').sum()
# Out:
#                  POST
# TAGS
# TagName           0.0
# assembly      34852.0
# c            336042.0
# c#          1423530.0
# c++          684210.0
# delphi        46212.0
# go            47499.0
# java        1696403.0
# javascript  2056510.0
# perl          65286.0
# php         1361988.0
# python      1496210.0
# r            356799.0
# ruby         214582.0
# swift        273055.0

# %%
df['DATE'][1]
# Out:
# '2008-07-01 00:00:00'

# %%
type(df['DATE'][1])
# Out:
# str

# %%
type(pd.to_datetime(df['DATE'][1]))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
reshaped_df = df.pivot(index='DATE', columns='TAGS', values='POST')
reshaped_df
# Out:
# TAGS        TagName  assembly       c       c#     c++  delphi     go  \
# DATE
# NaT             NaN       NaN     NaN      NaN     NaN     NaN    NaN
# 2008-07-01      NaN       NaN     NaN      3.0     NaN     NaN    NaN
# 2008-08-01      NaN       8.0    85.0    511.0   164.0    14.0    NaN
# 2008-09-01      NaN      28.0   321.0   1649.0   755.0   105.0    NaN
# 2008-10-01      NaN      15.0   303.0   1989.0   811.0   112.0    NaN
# ...             ...       ...     ...      ...     ...     ...    ...
# 2020-03-01      NaN     317.0  2670.0   8954.0  5107.0   181.0  719.0
# 2020-04-01      NaN     406.0  3472.0  10042.0  6820.0   250.0  887.0
# 2020-05-01      NaN     386.0  3602.0   9923.0  7063.0   221.0  826.0
# 2020-06-01      NaN     363.0  2757.0   9064.0  6161.0   214.0  765.0
# 2020-07-01      NaN     298.0  2294.0   9145.0  5756.0   212.0  743.0
#
# TAGS           java  javascript   perl     php   python       r   ruby   swift
# DATE
# NaT             NaN         NaN    NaN     NaN      NaN     NaN    NaN     NaN
# 2008-07-01      NaN         NaN    NaN     NaN      NaN     NaN    NaN     NaN
# 2008-08-01    222.0       162.0   28.0   161.0    124.0     NaN   73.0     NaN
# 2008-09-01   1137.0       640.0  131.0   482.0    542.0     6.0  290.0     NaN
# 2008-10-01   1153.0       725.0  127.0   617.0    510.0     NaN  249.0     NaN
# ...             ...         ...    ...     ...      ...     ...    ...     ...
# 2020-03-01  13253.0     20483.0  215.0  6672.0  26673.0  5761.0  780.0  3434.0
# 2020-04-01  15377.0     24634.0  240.0  8060.0  32605.0  7047.0  860.0  4015.0
# 2020-05-01  14711.0     25196.0  228.0  7917.0  34478.0  6833.0  774.0  4066.0
# 2020-06-01  13015.0     23360.0  203.0  7188.0  31817.0  6249.0  670.0  3733.0
# 2020-07-01  12723.0     23802.0  182.0  7334.0  31261.0  5694.0  775.0  3607.0
#
# [146 rows x 15 columns]

# %%
reshaped_df.head()
# Out:
# TAGS        TagName  assembly      c      c#    c++  delphi  go    java  \
# DATE
# NaT             NaN       NaN    NaN     NaN    NaN     NaN NaN     NaN
# 2008-07-01      NaN       NaN    NaN     3.0    NaN     NaN NaN     NaN
# 2008-08-01      NaN       8.0   85.0   511.0  164.0    14.0 NaN   222.0
# 2008-09-01      NaN      28.0  321.0  1649.0  755.0   105.0 NaN  1137.0
# 2008-10-01      NaN      15.0  303.0  1989.0  811.0   112.0 NaN  1153.0
#
# TAGS        javascript   perl    php  python    r   ruby  swift
# DATE
# NaT                NaN    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-07-01         NaN    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-08-01       162.0   28.0  161.0   124.0  NaN   73.0    NaN
# 2008-09-01       640.0  131.0  482.0   542.0  6.0  290.0    NaN
# 2008-10-01       725.0  127.0  617.0   510.0  NaN  249.0    NaN

# %%
reshaped_df.tail()
# Out:
# TAGS        TagName  assembly       c       c#     c++  delphi     go  \
# DATE
# 2020-03-01      NaN     317.0  2670.0   8954.0  5107.0   181.0  719.0
# 2020-04-01      NaN     406.0  3472.0  10042.0  6820.0   250.0  887.0
# 2020-05-01      NaN     386.0  3602.0   9923.0  7063.0   221.0  826.0
# 2020-06-01      NaN     363.0  2757.0   9064.0  6161.0   214.0  765.0
# 2020-07-01      NaN     298.0  2294.0   9145.0  5756.0   212.0  743.0
#
# TAGS           java  javascript   perl     php   python       r   ruby   swift
# DATE
# 2020-03-01  13253.0     20483.0  215.0  6672.0  26673.0  5761.0  780.0  3434.0
# 2020-04-01  15377.0     24634.0  240.0  8060.0  32605.0  7047.0  860.0  4015.0
# 2020-05-01  14711.0     25196.0  228.0  7917.0  34478.0  6833.0  774.0  4066.0
# 2020-06-01  13015.0     23360.0  203.0  7188.0  31817.0  6249.0  670.0  3733.0
# 2020-07-01  12723.0     23802.0  182.0  7334.0  31261.0  5694.0  775.0  3607.0

# %%
reshaped_df.count()
# Out:
# TAGS
# TagName         0
# assembly      144
# c             144
# c#            145
# c++           144
# delphi        144
# go            129
# java          144
# javascript    144
# perl          144
# php           144
# python        144
# r             142
# ruby          144
# swift         135
# dtype: int64

# %%
reshaped_df.columns
# Out:
# Index(['TagName', 'assembly', 'c', 'c#', 'c++', 'delphi', 'go', 'java',
#        'javascript', 'perl', 'php', 'python', 'r', 'ruby', 'swift'],
#       dtype='object', name='TAGS')

# %%
reshaped_df.shape
# Out:
# (146, 15)

# %%
reshaped_df.fillna(0, inplace=True)

# %%
reshaped_df.head()
# Out:
# TAGS        TagName  assembly      c      c#    c++  delphi  go    java  \
# DATE
# NaT             NaN       NaN    NaN     NaN    NaN     NaN NaN     NaN
# 2008-07-01      NaN       NaN    NaN     3.0    NaN     NaN NaN     NaN
# 2008-08-01      NaN       8.0   85.0   511.0  164.0    14.0 NaN   222.0
# 2008-09-01      NaN      28.0  321.0  1649.0  755.0   105.0 NaN  1137.0
# 2008-10-01      NaN      15.0  303.0  1989.0  811.0   112.0 NaN  1153.0
#
# TAGS        javascript   perl    php  python    r   ruby  swift
# DATE
# NaT                NaN    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-07-01         NaN    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-08-01       162.0   28.0  161.0   124.0  NaN   73.0    NaN
# 2008-09-01       640.0  131.0  482.0   542.0  6.0  290.0    NaN
# 2008-10-01       725.0  127.0  617.0   510.0  NaN  249.0    NaN

# %%
reshaped_df.isna().values.any()
# Out:
# False

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(reshaped_df.index, reshaped_df.java)

# %%
plt.figure(figsize=(16,10))
plt.plot(reshaped_df.index, reshaped_df.java)

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.plot(reshaped_df.index, reshaped_df.java)

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.plot(reshaped_df.index, reshaped_df.java)

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)
plt.plot(reshaped_df.index, reshaped_df.java, reshaped_df.python)
# Out:
# [<matplotlib.lines.Line2D at 0x7f9c7627c590>,
#  <matplotlib.lines.Line2D at 0x7f9c7622ea50>]

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)

for column in reshaped_df.columns:
  plt.plot(reshaped_df.index, reshaped_df[column])

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)

for column in reshaped_df.columns:
  plt.plot(reshaped_df.index, reshaped_df[column], linewidth=3, label=reshaped_df[column].name)

plt.legend(fontsize=16)

# %%
roll_df = reshaped_df.rolling(window=6).mean()

plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)

for column in roll_df.columns:
  plt.plot(roll_df.index, roll_df[column], linewidth=3, label=roll_df[column].name)

plt.legend(fontsize=16)

# %%
roll_df = reshaped_df.rolling(window=3).mean()

plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)

for column in roll_df.columns:
  plt.plot(roll_df.index, roll_df[column], linewidth=3, label=roll_df[column].name)

plt.legend(fontsize=16)

# %%
roll_df = reshaped_df.rolling(window=12).mean()

plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)

for column in roll_df.columns:
  plt.plot(roll_df.index, roll_df[column], linewidth=3, label=roll_df[column].name)

plt.legend(fontsize=16)
